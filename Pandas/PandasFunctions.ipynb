# %% [markdown]
# # Pandas Functions

# %%
import pandas as pd

csv_1 = pd.read_csv("//Users//princemaurya//Desktop//Jupyter//stock_data.csv")

csv_1
# Out:
#         SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0   ELECTTHERM          Electrotherm (India) Limited          473907
# 1       NBIFIN   N. B. I. Industrial Finance Company            5754
# 2      HINDCON             Hindcon Chemicals Limited          304759
# 3   GKWLIMITED                           GKW Limited           21375
# 4   21STCENMGM      21st Century Management Services          110375
# 5     ALPHAGEO              Alphageo (India) Limited          232755
# 6     UNIENTER           Uniphos Enterprises Limited          162601
# 7   JAGSNPHARM     Jagsonpal Pharmaceuticals Limited         1301892
# 8   SKMEGGPROD   SKM Egg Products Export (India) Ltd         1541130
# 9    SWELECTES        Swelect Energy Systems Limited          207954
# 10   NAHARPOLY              Nahar Poly Films Limited          600043
# 11  PODDARHOUS        Poddar Housing and Development           46040
# 12        LINC                          Linc Limited           60551
# ...

# %% [markdown]
# agar hme sirf index get krna hai then use

# %%
csv_1.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %% [markdown]
# agar hme sirf column get krna hai then use

# %%
csv_1.columns
# Out:
# Index(['SYMBOL', 'SECURITY', 'TODAY - VOLUME', 'AVG. VOLUME', 'CHANGE'], dtype='object')

# %% [markdown]
# agar hme sare integer value ka count,mean,std,min,25%,50% etc chahiye than use describe function

# %%
csv_1.describe()
# Out:
#        TODAY - VOLUME    AVG. VOLUME     CHANGE
# count    2.500000e+01      25.000000  25.000000
# mean     8.025246e+05   71237.280000  17.885833
# std      1.397036e+06  139964.776177  10.809391
# min      5.754000e+03     154.000000   7.606862
# 25%      1.574960e+05    8356.000000  10.049914
# 50%      3.047590e+05   19059.000000  14.853673
# 75%      7.053220e+05   82307.000000  21.528002
# max      6.864080e+06  685602.000000  50.110003

# %% [markdown]
# agar hme sheet ke andar ke fixed amount of data ko dekhana hai than use head & tail function (for above and bottom) by default it shows 5

# %%
csv_1.head(2)
# Out:
#        SYMBOL                             SECURITY  TODAY - VOLUME  \
# 0  ELECTTHERM         Electrotherm (India) Limited          473907
# 1      NBIFIN  N. B. I. Industrial Finance Company            5754
#
#    AVG. VOLUME     CHANGE
# 0         9457  50.110003
# 1          154  37.202586

# %%
csv_1.tail()
# Out:
#         SYMBOL                              SECURITY  TODAY - VOLUME  \
# 20  BHAGYAPROP        Bhagyanagar Properties Limited          305594
# 21    MUNJALAU        Munjal Auto Industries Limited          705322
# 22      ALKALI                 Alkali Metals Limited          157496
# 23   INTENTECH          Intense Technologies Limited         1252606
# 24    INDORAMA  Indo Rama Synthetics (India) Limited          679204
#
#     AVG. VOLUME    CHANGE
# 20        30596  9.987766
# 21        82307  8.569318
# 22        19059  8.263315
# 23       164644  7.607959
# 24        89288  7.606862

# %% [markdown]
# agar hm chahte hai ki starting se lekar hme 1no. tk ka data mil jaye than [:2] similar like string slicing

# %%
csv_1[:2]
# Out:
#        SYMBOL                             SECURITY  TODAY - VOLUME  \
# 0  ELECTTHERM         Electrotherm (India) Limited          473907
# 1      NBIFIN  N. B. I. Industrial Finance Company            5754
#
#    AVG. VOLUME     CHANGE
# 0         9457  50.110003
# 1          154  37.202586

# %% [markdown]
# agar hme kisi particular range ka data chahiye then use

# %%
csv_1[6:11]
# Out:
#         SYMBOL                             SECURITY  TODAY - VOLUME  \
# 6     UNIENTER          Uniphos Enterprises Limited          162601
# 7   JAGSNPHARM    Jagsonpal Pharmaceuticals Limited         1301892
# 8   SKMEGGPROD  SKM Egg Products Export (India) Ltd         1541130
# 9    SWELECTES       Swelect Energy Systems Limited          207954
# 10   NAHARPOLY             Nahar Poly Films Limited          600043
#
#     AVG. VOLUME     CHANGE
# 6          7553  21.528002
# 7         73134  17.801420
# 8         87775  17.557733
# 9         12276  16.938733
# 10        38574  15.555297

# %%
print(type(csv_1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# agar hme csv file ke index ko array me dikhana chahte hai than use

# %%
csv_1.index.array
# Out:
# <NumpyExtensionArray>
# [ np.int64(0),  np.int64(1),  np.int64(2),  np.int64(3),  np.int64(4),
#   np.int64(5),  np.int64(6),  np.int64(7),  np.int64(8),  np.int64(9),
#  np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14),
#  np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19),
#  np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24)]
# Length: 25, dtype: int64

# %% [markdown]
# ise hm numpy array me bhi convert kr skte hai

# %%
csv_1.to_numpy()
# Out:
# array([['ELECTTHERM', 'Electrotherm (India) Limited', 473907, 9457,
#         50.11000282],
#        ['NBIFIN', 'N. B. I. Industrial Finance Company', 5754, 154,
#         37.20258621],
#        ['HINDCON', 'Hindcon Chemicals Limited', 304759, 9248,
#         32.95345023],
#        ['GKWLIMITED', 'GKW Limited', 21375, 711, 30.04920337],
#        ['21STCENMGM', '21st Century Management Services', 110375, 3879,
#         28.45083129],
#        ['ALPHAGEO', 'Alphageo (India) Limited', 232755, 8356,
#         27.85261268],
#        ['UNIENTER', 'Uniphos Enterprises Limited', 162601, 7553,
#         21.52800212],
#        ['JAGSNPHARM', 'Jagsonpal Pharmaceuticals Limited', 1301892,
#         73134, 17.80141977],
#        ['SKMEGGPROD', 'SKM Egg Products Export (India) Ltd', 1541130,
#         87775, 17.55773284],
#        ['SWELECTES', 'Swelect Energy Systems Limited', 207954, 12276,
#         16.93873284],
#        ['NAHARPOLY', 'Nahar Poly Films Limited', 600043, 38574,
# ...

# %% [markdown]
# also use another function to convert into array

# %%
import numpy as np

v = np.asarray(csv_1)
v
# Out:
# array([['ELECTTHERM', 'Electrotherm (India) Limited', 473907, 9457,
#         50.11000282],
#        ['NBIFIN', 'N. B. I. Industrial Finance Company', 5754, 154,
#         37.20258621],
#        ['HINDCON', 'Hindcon Chemicals Limited', 304759, 9248,
#         32.95345023],
#        ['GKWLIMITED', 'GKW Limited', 21375, 711, 30.04920337],
#        ['21STCENMGM', '21st Century Management Services', 110375, 3879,
#         28.45083129],
#        ['ALPHAGEO', 'Alphageo (India) Limited', 232755, 8356,
#         27.85261268],
#        ['UNIENTER', 'Uniphos Enterprises Limited', 162601, 7553,
#         21.52800212],
#        ['JAGSNPHARM', 'Jagsonpal Pharmaceuticals Limited', 1301892,
#         73134, 17.80141977],
#        ['SKMEGGPROD', 'SKM Egg Products Export (India) Ltd', 1541130,
#         87775, 17.55773284],
#        ['SWELECTES', 'Swelect Energy Systems Limited', 207954, 12276,
#         16.93873284],
#        ['NAHARPOLY', 'Nahar Poly Films Limited', 600043, 38574,
# ...

# %% [markdown]
# agar hme data ko descending order me show krna hai than use

# %%
csv_1.sort_index(axis=0,ascending=False)
# Out:
#         SYMBOL                              SECURITY  TODAY - VOLUME  \
# 24    INDORAMA  Indo Rama Synthetics (India) Limited          679204
# 23   INTENTECH          Intense Technologies Limited         1252606
# 22      ALKALI                 Alkali Metals Limited          157496
# 21    MUNJALAU        Munjal Auto Industries Limited          705322
# 20  BHAGYAPROP        Bhagyanagar Properties Limited          305594
# 19      PILITA         PIL ITALICA LIFESTYLE LIMITED         6864080
# 18        REPL      Rudrabhishek Enterprises Limited          660281
# 17    LAXMICOT                 Laxmi Cotspin Limited          198503
# 16    ANDREWYU         Andrew Yule & Company Limited         2448026
# 15        DSSL  Dynacons Systems & Solutions Limited          263641
# 14  PDMJEPAPER       Pudumjee Paper Products Limited         1316284
# 13  SHIVAMILLS                   Shiva Mills Limited          142943
# 12        LINC                          Linc Limited           60551
# ...

# %% [markdown]
# agar hme kisi column ke andar ka data change karna hai then use

# %%
csv_1.loc[0,"SYMBOL"] = "python"

csv_1
# Out:
#         SYMBOL                              SECURITY  TODAY - VOLUME  \
# 0       python          Electrotherm (India) Limited          473907
# 1       NBIFIN   N. B. I. Industrial Finance Company            5754
# 2      HINDCON             Hindcon Chemicals Limited          304759
# 3   GKWLIMITED                           GKW Limited           21375
# 4   21STCENMGM      21st Century Management Services          110375
# 5     ALPHAGEO              Alphageo (India) Limited          232755
# 6     UNIENTER           Uniphos Enterprises Limited          162601
# 7   JAGSNPHARM     Jagsonpal Pharmaceuticals Limited         1301892
# 8   SKMEGGPROD   SKM Egg Products Export (India) Ltd         1541130
# 9    SWELECTES        Swelect Energy Systems Limited          207954
# 10   NAHARPOLY              Nahar Poly Films Limited          600043
# 11  PODDARHOUS        Poddar Housing and Development           46040
# 12        LINC                          Linc Limited           60551
# ...

# %% [markdown]
# loc function ka use krke hm kisi particular data ko bhi get kr skte hai

# %%
csv_1.loc[[2,3],["SYMBOL","SECURITY"]]
# Out:
#        SYMBOL                   SECURITY
# 2     HINDCON  Hindcon Chemicals Limited
# 3  GKWLIMITED                GKW Limited

# %% [markdown]
# agar hme SYMBOL & SECURITY ka sara data chahiye then use

# %%
csv_1.loc[:,["SYMBOL","SECURITY"]]
# Out:
#         SYMBOL                              SECURITY
# 0       python          Electrotherm (India) Limited
# 1       NBIFIN   N. B. I. Industrial Finance Company
# 2      HINDCON             Hindcon Chemicals Limited
# 3   GKWLIMITED                           GKW Limited
# 4   21STCENMGM      21st Century Management Services
# 5     ALPHAGEO              Alphageo (India) Limited
# 6     UNIENTER           Uniphos Enterprises Limited
# 7   JAGSNPHARM     Jagsonpal Pharmaceuticals Limited
# 8   SKMEGGPROD   SKM Egg Products Export (India) Ltd
# 9    SWELECTES        Swelect Energy Systems Limited
# 10   NAHARPOLY              Nahar Poly Films Limited
# 11  PODDARHOUS        Poddar Housing and Development
# 12        LINC                          Linc Limited
# 13  SHIVAMILLS                   Shiva Mills Limited
# 14  PDMJEPAPER       Pudumjee Paper Products Limited
# 15        DSSL  Dynacons Systems & Solutions Limited
# 16    ANDREWYU         Andrew Yule & Company Limited
# ...

# %% [markdown]
# similary agar hme sirf 2,3 ka data chahiye then use

# %%
csv_1.loc[[2,3],:]
# Out:
#        SYMBOL                   SECURITY  TODAY - VOLUME  AVG. VOLUME  \
# 2     HINDCON  Hindcon Chemicals Limited          304759         9248
# 3  GKWLIMITED                GKW Limited           21375          711
#
#       CHANGE
# 2  32.953450
# 3  30.049203

# %% [markdown]
# agar hme kisi bhi row ke particular data ko get karna hai then use iloc method

# %%
csv_1.iloc[0,1]
# Out:
# 'Electrotherm (India) Limited'

# %%
csv_1.iloc[0,2]
# Out:
# np.int64(473907)

# %% [markdown]
# if we want to drop a particular column

# %%
csv_1.drop("SECURITY",axis=1)
# Out:
#         SYMBOL  TODAY - VOLUME  AVG. VOLUME     CHANGE
# 0       python          473907         9457  50.110003
# 1       NBIFIN            5754          154  37.202586
# 2      HINDCON          304759         9248  32.953450
# 3   GKWLIMITED           21375          711  30.049203
# 4   21STCENMGM          110375         3879  28.450831
# 5     ALPHAGEO          232755         8356  27.852613
# 6     UNIENTER          162601         7553  21.528002
# 7   JAGSNPHARM         1301892        73134  17.801420
# 8   SKMEGGPROD         1541130        87775  17.557733
# 9    SWELECTES          207954        12276  16.938733
# 10   NAHARPOLY          600043        38574  15.555297
# 11  PODDARHOUS           46040         3012  15.283833
# 12        LINC           60551         4076  14.853673
# 13  SHIVAMILLS          142943        10391  13.755541
# 14  PDMJEPAPER         1316284       102646  12.823425
# 15        DSSL          263641        23439  11.247963
# ...

# %% [markdown]
# if we want to drop a particular row

# %%
csv_1.drop(0,axis=0)
# Out:
#         SYMBOL                              SECURITY  TODAY - VOLUME  \
# 1       NBIFIN   N. B. I. Industrial Finance Company            5754
# 2      HINDCON             Hindcon Chemicals Limited          304759
# 3   GKWLIMITED                           GKW Limited           21375
# 4   21STCENMGM      21st Century Management Services          110375
# 5     ALPHAGEO              Alphageo (India) Limited          232755
# 6     UNIENTER           Uniphos Enterprises Limited          162601
# 7   JAGSNPHARM     Jagsonpal Pharmaceuticals Limited         1301892
# 8   SKMEGGPROD   SKM Egg Products Export (India) Ltd         1541130
# 9    SWELECTES        Swelect Energy Systems Limited          207954
# 10   NAHARPOLY              Nahar Poly Films Limited          600043
# 11  PODDARHOUS        Poddar Housing and Development           46040
# 12        LINC                          Linc Limited           60551
# 13  SHIVAMILLS                   Shiva Mills Limited          142943
# ...
